# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikAfham/bug-free-invention/blob/main/Afham_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/Insiya24/datasets/main/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition              Department  DistanceFromHome EducationField  \
# 0   41       Yes                   Sales                 1  Life Sciences
# 1   49        No  Research & Development                 8  Life Sciences
# 2   37       Yes  Research & Development                 2          Other
# 3   33        No  Research & Development                 3  Life Sciences
# 4   27        No  Research & Development                 2        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0            1.0             1.0                      2.0  Female        94.0
# 1            1.0             2.0                      3.0    Male        61.0
# 2            1.0             4.0                      4.0    Male        92.0
# 3            1.0             5.0                      4.0  Female        56.0
# 4            NaN             7.0                      1.0    Male        40.0
#
# ...

# %%
data.tail()
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1467   27        No  Research & Development                 4  Life Sciences
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# 1465            1.0          2061.0                      3.0   Male
# 1466            1.0          2062.0                      4.0   Male
# 1467            1.0          2064.0                      2.0   Male
# 1468            1.0          2065.0                      4.0   Male
# 1469            1.0          2068.0                      2.0   Male
#
#       HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# ...

# %%
data_Gby= data.groupby(["Age"])[["EducationField"]]

# %%
data['DistanceFromHome'].mean()
# Out:
# 9.19251700680272

# %%
data['DistanceFromHome'].fillna(9.19251,inplace=True)

# %%
data['EnvironmentSatisfaction'].mean()
# Out:
# 2.7229407760381212

# %%
data['EnvironmentSatisfaction'].fillna(2.7229,inplace=True)

# %%
data['HourlyRate'].mean()
# Out:
# 65.88207225630539

# %%
data['HourlyRate'].fillna(65.8820,inplace=True)

# %%
data['MonthlyRate'].mean()
# Out:
# 14313.103401360544

# %%
data['MonthlyRate'].fillna(14313.103,inplace=True)

# %%
data['PercentSalaryHike'].mean()
# Out:
# 15.220628415300547

# %%
data['PercentSalaryHike'].fillna(15.2206,inplace=True)

# %%
data['YearsSinceLastPromotion'].mean()
# Out:
# 2.1877551020408164

# %%
data['YearsSinceLastPromotion'].fillna(2.18775,inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# Department                   2
# DistanceFromHome             0
# EducationField              19
# EmployeeCount                2
# EmployeeNumber               2
# EnvironmentSatisfaction      0
# Gender                      12
# HourlyRate                   0
# JobInvolvement              21
# JobLevel                    14
# JobSatisfaction             11
# MaritalStatus                0
# MonthlyIncome                0
# MonthlyRate                  0
# OverTime                     0
# PercentSalaryHike            0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# TotalWorkingYears            0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsSinceLastPromotion      0
# dtype: int64

# %%
data['EmployeeCount'].mean()
# Out:
# 1.0

# %%
data['EmployeeCount'].fillna(1.0,inplace=True)

# %%
data['JobInvolvement'].mean()
# Out:
# 2.732919254658385

# %%
data['JobInvolvement'].fillna(2.7323,inplace=True)

# %%
data['JobSatisfaction'].mean()
# Out:
# 2.726525017135024

# %%
data['JobSatisfaction'].fillna(2.7265,inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# Department                   2
# DistanceFromHome             0
# EducationField              19
# EmployeeCount                0
# EmployeeNumber               2
# EnvironmentSatisfaction      0
# Gender                      12
# HourlyRate                   0
# JobInvolvement               0
# JobLevel                    14
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome                0
# MonthlyRate                  0
# OverTime                     0
# PercentSalaryHike            0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# TotalWorkingYears            0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsSinceLastPromotion      0
# dtype: int64

# %%
data['JobLevel'].mean()
# Out:
# 2.0611263736263736

# %%
data['JobLevel'].fillna(2.0611,inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# Department                   2
# DistanceFromHome             0
# EducationField              19
# EmployeeCount                0
# EmployeeNumber               2
# EnvironmentSatisfaction      0
# Gender                      12
# HourlyRate                   0
# JobInvolvement               0
# JobLevel                     0
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome                0
# MonthlyRate                  0
# OverTime                     0
# PercentSalaryHike            0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# TotalWorkingYears            0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsSinceLastPromotion      0
# dtype: int64

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      874
# Female    584
# Name: count, dtype: int64

# %%
from sklearn import preprocessing
LE = preprocessing.LabelEncoder()

# %%
data["Gender"] = LE.fit_transform(data["Gender"])

# %%
data["Gender"].value_counts()
# Out:
# Gender
# 1    874
# 0    584
# 2     12
# Name: count, dtype: int64

# %%
data["EducationField"].value_counts()
# Out:
# EducationField
# Life Sciences       600
# Medical             454
# Marketing           159
# Technical Degree    131
# Other                81
# Human Resources      26
# Name: count, dtype: int64

# %%
data["EducationField"] = LE.fit_transform(data["EducationField"])

# %%
data["EducationField"].value_counts()
# Out:
# EducationField
# 1    600
# 3    454
# 2    159
# 5    131
# 4     81
# 0     26
# 6     19
# Name: count, dtype: int64

# %%
data["Department"].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     444
# Human Resources            63
# Name: count, dtype: int64

# %%
data["Department"] = LE.fit_transform(data["Department"])

# %%
data["OverTime"].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
data["OverTime"] = LE.fit_transform(data["OverTime"])

# %%
data["OverTime"].value_counts()
# Out:
# OverTime
# 0    1054
# 1     416
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# Department                  0
# DistanceFromHome            0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              2
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# TotalWorkingYears           0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# dtype: int64

# %%
data['EmployeeNumber'].median()
# Out:
# 1023.0

# %%
data['EmployeeNumber'].fillna(1023.0,inplace=True)

# %%
data
# Out:
#       Age Attrition  Department  DistanceFromHome  EducationField  \
# 0      41       Yes           2                 1               1
# 1      49        No           1                 8               1
# 2      37       Yes           1                 2               4
# 3      33        No           1                 3               1
# 4      27        No           1                 2               3
# ...   ...       ...         ...               ...             ...
# 1465   36        No           1                23               3
# 1466   39        No           1                 6               3
# 1467   27        No           1                 4               1
# 1468   49        No           2                 2               3
# 1469   34        No           1                 8               3
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0               1.0             1.0                      2.0       0
# ...

# %%
data["Attrition"] = LE.fit_transform(data["Attrition"])

# %%
data
# Out:
#       Age  Attrition  Department  DistanceFromHome  EducationField  \
# 0      41          1           2                 1               1
# 1      49          0           1                 8               1
# 2      37          1           1                 2               4
# 3      33          0           1                 3               1
# 4      27          0           1                 2               3
# ...   ...        ...         ...               ...             ...
# 1465   36          0           1                23               3
# 1466   39          0           1                 6               3
# 1467   27          0           1                 4               1
# 1468   49          0           2                 2               3
# 1469   34          0           1                 8               3
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0               1.0             1.0                      2.0       0
# ...

# %%
data.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# Department                    int64
# DistanceFromHome              int64
# EducationField                int64
# EmployeeCount               float64
# EmployeeNumber              float64
# EnvironmentSatisfaction     float64
# Gender                        int64
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobSatisfaction             float64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# OverTime                      int64
# PercentSalaryHike           float64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StandardHours                 int64
# TotalWorkingYears             int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsSinceLastPromotion       int64
# dtype: object

# %%
for column in data.select_dtypes(include=['object']):
    data[column].fillna(data[column].mode()[0], inplace=True)

# %%
data.drop(columns=['EmployeeNumber', 'MaritalStatus'], inplace=True)

# %%
import seaborn as SB
import matplotlib.pyplot as MPL

MPL.figure(figsize=(20,20))
correlation = data.corr()
heatmap = SB.heatmap(correlation, annot=True)
MPL.show()

# %% [markdown]
# **SUBMITTED BY AFHAMULLAH SHAIK MOHAMMED **
